# %% [markdown]
# <a href="https://colab.research.google.com/github/NealKumawat/JECRC-Angry-Birds/blob/main/JECRC_Angry_Birds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Plotting in Python

# %% [markdown]
# # Mounting Drive in Python

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Using CSV of data from Drive
# Data was asked from an audience for a Psychological report. The asked said, "If you have to rate your anger issues on a scale from 0 to 100, how much you rate it."
#
# Then it was saved as a CSV file.

# %%
# !ls /content/drive/My\ Drive

# %% [markdown]
# # Importing Packages
# Matplotlib is used to plot graphs in Python.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # CSV is read

# %%
df=pd.read_csv("/content/drive/My Drive/finalp.csv")

# %% [markdown]
# # Conversion of Data
# Now this is data was normal distribution so was converted into interval by using dictionary. A structure of dictionary was created and intervals like 0-10, 10-20,...,90-100 were created, and data was arranged in these intervals.

# %%
dict = {0:0, 10:0, 20:0, 30:0, 40:0, 50:0, 60:0, 70:0, 80:0, 90:0}
for i in df['data']:
  if i <= 10:
    dict[0] = dict[0] + 1
  if i>10 and i<=20:
    dict[10] = dict[10] + 1
  if i>20 and i<=30:
    dict[20] = dict[20] + 1
  if i>30 and i<=40:
    dict[30] = dict[30] + 1
  if i>40 and i<=50:
    dict[40] = dict[40] + 1
  if i>50 and i<=60:
    dict[50] = dict[50] + 1
  if i>60 and i<=70:
    dict[60] = dict[60] + 1
  if i>70 and i<=80:
    dict[70] = dict[70] + 1
  if i>80 and i<=90:
    dict[80] = dict[80] + 1
  if i>90 and i<=100:
    dict[90] = dict[90] + 1

# %% [markdown]
# # Graph formation
# X and Y axes are defined from the dictionary. Figure size is set and a line graph is formed. Labels, ticks, Title of the graph and more attributes which make the graph appealing are added.

# %%
x=list(dict.keys())
y=list(dict.values())
plt.figure(figsize=(9,5))
plt.plot(x,y, color='purple', marker='o', linewidth=1, markersize=5, markerfacecolor='yellow', label='Number of people having anger issues')
plt.xticks(ticks=range(0,101,5), labels=range(0,101,5))
plt.yticks(range(0,23,2))
plt.title("JECRC Angry Birds")
plt.grid(color='grey', linestyle='--', linewidth = 0.5, alpha=1)
plt.xlabel("Percentage", color='maroon', fontweight='bold')
plt.ylabel("Number of people", color='maroon', fontweight='bold')
plt.tight_layout(pad=0.1)
plt.legend()
plt.show()

# %% [markdown]
# ![Screenshot 2024-11-25 133351.png](data:image/png;base64,...)
